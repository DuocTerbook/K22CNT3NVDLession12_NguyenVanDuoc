-- %% [markdown]
-- # [dbo].[NVD_SACH]

-- %%
USE [NgVanDuoc_2210900016]
GO

-- %%
/****** Object:  Table [dbo].[NVD_SACH]    Script Date: 7/11/2024 12:27:42 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NVD_SACH](
	[Nvd_MaSach] [char](5) NOT NULL,
	[Nvd_TenSach] [nvarchar](50) NULL,
	[Nvd_SoTrang] [int] NULL,
	[Nvd_NamXB] [int] NULL,
	[Nvd_MaTG] [char](5) NULL,
	[Nvd_TrangThai] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Nvd_MaSach] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NVD_TACGIA]

-- %%
/****** Object:  Table [dbo].[NVD_TACGIA]    Script Date: 7/11/2024 12:27:42 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NVD_TACGIA](
	[Nvd_MaTG] [char](5) NOT NULL,
	[Nvd_TenTacGia] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Nvd_MaTG] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NVD_SACH]

-- %%
INSERT [dbo].[NVD_SACH] ([Nvd_MaSach], [Nvd_TenSach], [Nvd_SoTrang], [Nvd_NamXB], [Nvd_MaTG], [Nvd_TrangThai]) VALUES (N'A04  ', N'Độc lập', 100, 1926, N'TG001', NULL)
INSERT [dbo].[NVD_SACH] ([Nvd_MaSach], [Nvd_TenSach], [Nvd_SoTrang], [Nvd_NamXB], [Nvd_MaTG], [Nvd_TrangThai]) VALUES (N'D01  ', N'Hòa Bình', 125, 1987, N'TG001', 1)
INSERT [dbo].[NVD_SACH] ([Nvd_MaSach], [Nvd_TenSach], [Nvd_SoTrang], [Nvd_NamXB], [Nvd_MaTG], [Nvd_TrangThai]) VALUES (N'G03  ', N'Chiến tranh', 200, 1879, N'TG002', 1)
INSERT [dbo].[NVD_SACH] ([Nvd_MaSach], [Nvd_TenSach], [Nvd_SoTrang], [Nvd_NamXB], [Nvd_MaTG], [Nvd_TrangThai]) VALUES (N'S02  ', N'Thỏ bảy màu', 150, 1968, N'TG002', 0)
GO

-- %% [markdown]
-- # [dbo].[NVD_TACGIA]

-- %%
INSERT [dbo].[NVD_TACGIA] ([Nvd_MaTG], [Nvd_TenTacGia]) VALUES (N'TG001', N'Nguyễn Văn Được')
INSERT [dbo].[NVD_TACGIA] ([Nvd_MaTG], [Nvd_TenTacGia]) VALUES (N'TG002', N'Phan Viết Vượng')
INSERT [dbo].[NVD_TACGIA] ([Nvd_MaTG], [Nvd_TenTacGia]) VALUES (N'TG003', N'Đinh Công Định')
GO

-- %% [markdown]
-- # [FR_NVD_TACGIA_NVD_SACH]

-- %%
ALTER TABLE [dbo].[NVD_SACH]  WITH CHECK ADD  CONSTRAINT [FR_NVD_TACGIA_NVD_SACH] FOREIGN KEY([Nvd_MaTG])
REFERENCES [dbo].[NVD_TACGIA] ([Nvd_MaTG])
GO
ALTER TABLE [dbo].[NVD_SACH] CHECK CONSTRAINT [FR_NVD_TACGIA_NVD_SACH]
GO
